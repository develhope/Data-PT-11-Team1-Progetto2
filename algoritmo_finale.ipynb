# %% [markdown]
# #Sistema di raccomandazione
# Il sistema implementa un approccio di raccomandazione one-time, evitando la costruzione di matrici di similarità NxN. Applica un filtro hard sulla categoria e combina una similarità basata su ingredienti con una funzione deterministica di brand e segmento, pesate rispettivamente 0.8 e 0.2.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) Importo il df e creo un nuovo df con le colonne d'interesse

# %%
df = pd.read_csv("brand_categoria.csv",dtype={"code": str})

df = df[['code', 'product_name','brand_name', 'brand_segment','macro_category']].copy()
df['code'] = df['code'].astype(str)
df['product_name'] = df['product_name'].astype(str)
df['brand_name'] = df['brand_name'].astype(str)
df['brand_segment'] = df['brand_segment'].astype(str)
df['macro_category'] = df['macro_category'].astype(str)


df.head(20)
# Out:
#              code                                       product_name  \
# 0   5013965698897                                                  1
# 1     88582000939                                                  2
# 2   0650240025396                              zan zusi b b flash 30
# 3   3560070084074                                     deo men marine
# 4   6134598000044                            savon liquide main life
# 5   5943044010046                                         gerocossen
# 6        20546472                                               cien
# 7   3700216252688                                 glycerine vegetale
# 8   8859423200212                                             habino
# 9   6130460000747                                                nan
# 10  5600380895293                                l citrulline malate
# 11  3574661599281                       johnson baby wipes 2yrs prod
# 12  3600523709649                               elseve rapid restore
# 13  8710871392327                                     balsam tissues
# 14  0850028447840                                          full mega
# 15  0633911616277                                                  1
# 16  0716237185600  frizz be gone leave in conditioning styling el...
# 17  8718481351000                                          aloe vera
# 18  0740985223901                                      sentry senior
# 19  8436567350524                               night recovery cream
#
#         brand_name brand_segment macro_category
# 0                1   mass_market          Other
# 1                1   mass_market          Other
# 2                1   mass_market          Other
# 3   1 de carrefour   mass_market     Deodorants
# 4           100 da   mass_market        Hygiene
# 5               12   mass_market          Other
# 6               12   mass_market          Other
# 7       123gelules   mass_market          Other
# 8            13000   mass_market          Other
# 9            150da   mass_market          Other
# 10            150g   mass_market          Other
# 11         168 pcs   mass_market      Baby_Care
# 12          180 ml   mass_market          Other
# 13        1debeste   mass_market          Other
# 14       1st phorm   mass_market          Other
# 15               2   mass_market          Other
# 16          2 chic   mass_market      Hair_Care
# 17            2025   mass_market          Other
# 18      21 century   mass_market          Other
# 19          226ers   mass_market      Face_Care

# %%
df_ing = pd.read_csv("ingr_cat.csv",dtype={"code": str})


df_ing['code'] = df_ing['code'].astype(str)
df_ing['product_name'] = df_ing['product_name'].astype(str)
df_ing['macro_category'] = df_ing['macro_category'].astype(str)
df_ing['inci_name'] = df_ing['inci_name'].astype(str)

df_finale = (
    df_ing
    .groupby(['code', 'product_name', 'macro_category'])['inci_name']
    .apply(lambda lst: ", ".join(sorted(set(lst))))
    .reset_index()
    .rename(columns={'inci_name': 'ingredients'}))

df_finale.head(20)
# Out:
#              code                               product_name macro_category  \
# 0        00000014                            Süßlupinen Mehl          Other
# 1        00000311                Huile végétale Amande douce           Oils
# 2        00000511                       pure collagène marin          Other
# 3        00000561                        Huile végétale coco           Oils
# 4        00000587                        Macérât huileux Lys           Oils
# 5        00000695                               olé olé Aloé          Other
# 6        00000859                               Base lavante         Makeup
# 7        00000905                             Henné d'Egypte          Other
# 8        00001277                        Indian Healing Clay          Other
# 9   0000160332625                         Colgate toothpaste        Hygiene
# 10       00001785  Nutricentials, day dream protective cream      Face_Care
# 11       00002337                            Base shampooing      Hair_Care
# 12       00002369                  Crème neutre désaltérante      Face_Care
# 13       00002631                    Herbal Aloe Concentrado          Other
# 14       00002698              Gel douche sorbet de verveine      Body_Care
# 15       00002708                 Base micellaire concentrée         Makeup
# 16       00002979           Coloration végétale henné cuivré          Other
# 17       00002980                        Henné châtain foncé          Other
# 18       00004019                   Soin neutre Lait végétal          Other
# 19       00006582     Jardins du monde Fleur de coton d'Inde          Other
#
#                                           ingredients
# 0   Arnica Montana, Avoid Contact With Eyes, Burit...
# 1                                                 Oil
# 2   Added Sugarss, Colorings, Cr 6Ad, Croydon, Lac...
# 3                                                 Oil
# 4                 Lilium Candidum Flower Extract, Oil
# 5   Allantoin, Aloe Barbadensis Leaf Juice, Benzoi...
# 6   Coco-Glucoside, Decyl Glucoside, Glycerin, Gly...
# 7                        Lawsonia Inermis Leaf Powder
# 8                      Natural Calcium Bentonite Clay
# 9   Cellulose Gum, Citric Acid, Cocamidopropyl Bet...
# 10  Ammonium Acryloyldimethyltauratevp Copolymer, ...
# 11  Arginine, Babassuamidopropyl Betaine, Coco-Glu...
# 12  Aloe Barbadensis Leaf Extract, Cetearyl Olivat...
# 13  1 Ppm, 13 G100 G, Cido Ctrico Anhidro, Sabor N...
# 14  Benzyl Alcohol, Ci 75300, Citral, Coco-Glucosi...
# 15  Biosaccharide Gum-1, Glyceril Caprylate, Glyce...
# 16  Aloe Barbadensis Leaf Powder, Curcuma Longa Ro...
# 17  Curcuma Longa Root Powder, Emblica Officinalis...
# 18  Butyrospermum Parkii Butter, C10-18 Triglyceri...
# 19  Aluminum Chlorohydrate, Fragrance, Gossypium H...

# %%
#per la semplificazione della ricerca in fase di test, è una lista di "code" in comune tra i dataset
common_codes = set(df['code']).intersection(set(df_finale['code']))

print(f"Prodotti in df: {len(df)}")
print(f"Prodotti in df_finale: {len(df_finale)}")
print(f"Prodotti comuni: {len(common_codes)}")
common_codes
# Out:
# Prodotti in df: 31056
# Prodotti in df_finale: 15131
# Prodotti comuni: 12304
# {'5293796944527',
#  '3401351102882',
#  '3600531512088',
#  '8710908315244',
#  '3250391292738',
#  '3245678675090',
#  '42354840',
#  '8001090516152',
#  '30173552',
#  '7509552844221',
#  '4063528017796',
#  '4005808925124',
#  '5765228838471',
#  '3245678562901',
#  '8025796003822',
#  '7640183490699',
#  '8021983810051',
#  '2000000000727',
#  '5010123726621',
#  '5063334005894',
#  '4015600862459',
#  '3054080045465',
#  '3605971307928',
#  '3760075070045',
#  '3401346674455',
#  '4088700011775',
#  '20908621',
#  '4005900035622',
#  '3401560062816',
#  '8720181042638',
#  '8712561803847',
#  '4058172432675',
#  '3760099591496',
#  '4015000702652',
#  '8718951508507',
#  '4066447705027',
#  '0606345805944',
#  '7899846080665',
#  '3606000537613',
#  '4005808368303',
#  '5035832010274',
#  '8410412460026',
#  '3052505505105',
#  '42232216',
#  '5900095002789',
#  '4017645021082',
#  '26023229',
#  '0883140040231',
#  '20055929',
#  '8436045034052',
#  '2000000000894',
#  '4005900551559',
#  '8032755623021',
#  '0667557015040',
#  '4021457635436',
#  '4066447380439',
#  '8590031108841',
#  '3770013899034',
#  '4005900480392',
#  '3517360010145',
#  '3274872313187',
#  '4009800001671',
#  '8712561803274',
#  '3031449447153',
#  '3600522280897',
#  '8718951189287',
#  '4005900471574',
#  '8718951484672',
#  '3760211480066',
#  '8710522682272',
#  '8680722281202',
#  '8025916111246',
#  '3600523128174',
#  '8718951299146',
#  '3245678089651',
#  '8717163913970',
#  '4251347600958',
#  '3182611231039',
#  '4066447331295',
#  '3596710524068',
#  '5900249201549',
#  '3662217005147',
#  '3600550964714',
#  '0676280027091',
#  '8001090532183',
#  '42238935',
#  '3251248047327',
#  '3700172700179',
#  '7640183490378',
#  '3600550937435',
#  '4630262809187',
#  '2000000000897',
#  '4056489361251',
#  '6111103021190',
#  '3257984523521',
#  '7791293046365',
#  '5902399889844',
#  '3450601021879',
#  '3661434005534',
#  '8420906340017',
#  '3596710381289',
#  '3504105028312',
#  '4010355507280',
#  '3606000537729',
#  '8714789874883',
#  '3660005615776',
#  '3574661034867',
#  '3052503450407',
#  '4005808134830',
#  '4005808840113',
#  '3600550309256',
#  '3600531369484',
#  '7046110067567',
#  '5713868005722',
#  '4061458023658',
#  '0884486312983',
#  '3606000552555',
#  '8714789764795',
#  '0800897206963',
#  '3222472192787',
#  '3600542520263',
#  '8684149440259',
#  '14451171',
#  '0815921017118',
#  '3522930000792',
#  '5065018225079',
#  '8711700822985',
#  '7898581082309',
#  '3401353741591',
#  '6026000058401',
#  '5712874642297',
#  '0851939002005',
#  '7340011321514',
#  '7310610021269',
#  '3595894852813',
#  '29023639',
#  '3760354680019',
#  '8998866106474',
#  '8710908570599',
#  '3560070630509',
#  '3760004691419',
#  '8712561962407',
#  '3600531579463',
#  '3401360106994',
#  '5410091755355',
#  '8420075170088',
#  '8710447381946',
#  '7502276853685',
#  '4005808129447',
#  '4250587772173',
#  '3600523337576',
#  '4005808661411',
#  '8719238033286',
#  '40058153',
#  '3574660724349',
#  '0505581301063',
#  '2000000005167',
#  '8901314077059',
#  '3245678042205',
#  '3600522870586',
#  '6130552003793',
#  '8480000468710',
#  '7506306233355',
#  '0863765000087',
#  '0887167222243',
#  '8711700923323',
#  '8850006303306',
#  '3596206289112',
#  '4008491261746',
#  '20208844',
#  '5703147063420',
#  '8711600786226',
#  '8718951195837',
#  '8906058357580',
#  '3283950916776',
#  '3059948001447',
#  '8710908100680',
#  '3574661039060',
#  '4005808222919',
#  '4005900904881',
#  '3574661336657',
#  '3468080150157',
#  '5054563006592',
#  '3596209532666',
#  '4515061013228',
#  '8008970002859',
#  '30097001',
#  '7501026009396',
#  '3274872296138',
#  '87343595',
#  '3596490003593',
#  '7702031169536',
#  '1748567444460',
#  '3141380052818',
#  '4005900246592',
#  '9319871000639',
#  '0681131436472',
#  '8422410180523',
#  '8002410033618',
#  '3489941049762',
#  '3511720107100',
#  '3596710524129',
#  '8720181077692',
#  '3760177361607',
#  '4000388563902',
#  '8851111429035',
#  '3245678562338',
#  '6130601008663',
#  '3600541934047',
#  '8711600410367',
#  '8001120704788',
#  '8008277371566',
#  '3337872413025',
#  '3600520772011',
#  '3560070911554',
#  '3600550185263',
#  '20182359',
#  '3660005129419',
#  '4305615940311',
#  '5033102918084',
#  '3564700279007',
#  '3256224064541',
#  '0724742006907',
#  '3574661338439',
#  '3770022721043',
#  '8414807548610',
#  '3760354680323',
#  '8720181334030',
#  '8435415012669',
#  '3250391375370',
#  '3504108012936',
#  '3286010012777',
#  '4006000003894',
#  '3583788165637',
#  '3245678612446',
#  '3489940061574',
#  '3760257885115',
#  '3282770141436',
#  '0814627025137',
#  '3600530941278',
#  '3596710534883',
#  '0885229253723',
#  '3600520297118',
#  '4039175007398',
#  '3468080109896',
#  '4305615826103',
#  '7509546655000',
#  '2200281138364',
#  '4005900223944',
#  '8436044512087',
#  '8714789930893',
#  '8720181092800',
#  '3574660514520',
#  '3596710524426',
#  '4010355387325',
#  '5028197943103',
#  '8717163699263',
#  '8999338169881',
#  '5353065593655',
#  '4251082943914',
#  '8715342031606',
#  '6181100536553',
#  '3596710536719',
#  '5709404579932',
#  '4010355306517',
#  '3058320040210',
#  '4066447452778',
#  '7501056346287',
#  '3517360021141',
#  '80948919',
#  '4250587766011',
#  '5420073400098',
#  '0860002106816',
#  '3014230010262',
#  '0681131175869',
#  '3450601040238',
#  '3478820044035',
#  '5900998006556',
#  '3282770055023',
#  '4020829009240',
#  '3282779003131',
#  '8710604793568',
#  '3596710536689',
#  '8906014523004',
#  '8431876287783',
#  '3282779051514',
#  '9310645289441',
#  '5425015920207',
#  '3600541291287',
#  '8719134161090',
#  '0667554738485',
#  '3760209542530',
#  '3700454222894',
#  '3401397611669',
#  '7909189145713',
#  '8680690700408',
#  '7649991272039',
#  '8712561249119',
#  '8710522754597',
#  '3511720118601',
#  '3245678589809',
#  '3564700435748',
#  '3770013219177',
#  '3600542461870',
#  '8001090662231',
#  '3600550580051',
#  '3140100403763',
#  '7310610021207',
#  '0748378003154',
#  '3517360006278',
#  '7046110032329',
#  '8698703025202',
#  '8431876271478',
#  '7700304407576',
#  '3700076443998',
#  '3245678599846',
#  '3596710516933',
#  '4010355426116',
#  '4058172242984',
#  '42349358',
#  '7310181582190',
#  '4005900919564',
#  '3348901288545',
#  '3058320026047',
#  '4058172187247',
#  '7506339345247',
#  '8001090761187',
#  '8712561631662',
#  '3256225719174',
#  '06039307',
#  '3474637103569',
#  '0745114970503',
#  '3600550029758',
#  '3666085113690',
#  '3600523794881',
#  '3660005338682',
#  '0764302231059',
#  '8001280400865',
#  '24432191',
#  '24047357',
#  '3010351730256',
#  '0787790794998',
#  '96080894',
#  '7032069728567',
#  '3600540716323',
#  '8001090384034',
#  '7640183490224',
#  '3595890243462',
#  '3564700602874',
#  '3600541319769',
#  '4061458051293',
#  '8711700719308',
#  '42348542',
#  '6134041000140',
#  '3283950920834',
#  '7891150017337',
#  '3574661237848',
#  '3600531516765',
#  '08133025',
#  '5017634116088',
#  '3489940049367',
#  '8480000422224',
#  '7610108024612',
#  '0732913229307',
#  '3222476112224',
#  '4005808668649',
#  '3600531543310',
#  '8718951087569',
#  '96125694',
#  '3665467002584',
#  '7630028612683',
#  '07469688',
#  '4059729338907',
#  '9310692112198',
#  '7391681038653',
#  '3560070937493',
#  '0752830779389',
#  '5099514400074',
#  '7702018366200',
#  '8006540650318',
#  '8017331049037',
#  '3251248033108',
#  '8714789940892',
#  '8431876271690',
#  '3600542068475',
#  '4744183011977',
#  '3511720115143',
#  '3058320007022',
#  '8430830508216',
#  '3593290031993',
#  '3256226758158',
#  '3560070791552',
#  '5425001842223',
#  '4058172627484',
#  '3662217000784',
#  '7500435019828',
#  '3600542525657',
#  '3517360011302',
#  '2000000152396',
#  '3660005364544',
#  '4005808406029',
#  '3600551125275',
#  '7790801004422',
#  '3054080020028',
#  '8710447382158',
#  '4084500991507',
#  '3600550894967',
#  '3596710521593',
#  '8008277205083',
#  '3286010031020',
#  '3700763501581',
#  '3267822363134',
#  '3258561650104',
#  '3474630618435',
#  '3600540009012',
#  '4316268718165',
#  '4056489235620',
#  '3014260240226',
#  '3600531629106',
#  '4105170615538',
#  '7311041084977',
#  '3489940070590',
#  '4104260041714',
#  '8712100987243',
#  '3600541238176',
#  '80808756',
#  '8999908450906',
#  '3245678090497',
#  '7909589074651',
#  '3600550921045',
#  '2000000001060',
#  '8934868133391',
#  '0745114958167',
#  '4260491220257',
#  '0817891025254',
#  '8436542932493',
#  '8718951320239',
#  '3283950011068',
#  '8904006307151',
#  '5060178100679',
#  '3770022721050',
#  '3574661065359',
#  '4000196901187',
#  '3284410031015',
#  '4005900602114',
#  '0859581006747',
#  '3600523386314',
#  '0812192030051',
#  '0612082776010',
#  '4001638088565',
#  '3661434003394',
#  '3607345064505',
#  '4017645042247',
#  '3663787551875',
#  '0687735303905',
#  '3522931031887',
#  '8001841923765',
#  '3245678044469',
#  '5011417577387',
#  '8402001027307',
#  '7899846037645',
#  '3282779053266',
#  '3263855850016',
#  '8720181001833',
#  '3600523939718',
#  '3600542150415',
#  '8715342019727',
#  '3517360021509',
#  '4015000995054',
#  '3245678104002',
#  '4305615842424',
#  '3141380054911',
#  '3245678562031',
#  '3596710517046',
#  '4015600056155',
#  '6182000102725',
#  '35002130',
#  '4054495000614',
#  '7804920350831',
#  '5000101193620',
#  '7891350034844',
#  '3286010040664',
#  '3574661568928',
#  '3606000537606',
#  '4036221432302',
#  '5397212626070',
#  '3245678674888',
#  '7501056342999',
#  '8006540396049',
#  '3600542009966',
#  '8710847972720',
#  '8906007200097',
#  '0745114958297',
#  '23135123',
#  '3172350157134',
#  '3245678667897',
#  '20060923',
#  '5410076390779',
#  '4001638075114',
#  '0810071910692',
#  '8719874198240',
#  '0856017000126',
#  '4005800037535',
#  '3600540989253',
#  '3606000537712',
#  '42182740',
#  '59081586',
#  '8710908720451',
#  '4059729446992',
#  '3141380018944',
#  '3181730199978',
#  '8718951070226',
#  '4003583176298',
#  '3245678691496',
#  '4056489525882',
#  '4066447097795',
#  '8720182572202',
#  '3517360012811',
#  '3346022080000',
#  '0787734793087',
#  '20250867',
#  '3596710524341',
#  '3600541177741',
#  '8470001542410',
#  '4010355409256',
#  '4015400623496',
#  '8718951140721',
#  '7791293028835',
#  '0840044712404',
#  '9009695001324',
#  '3600550106541',
#  '5000209108519',
#  '7032069717455',
#  '5412058150555',
#  '8710447365342',
#  '3251248033009',
#  '59013631',
#  '5057753285807',
#  '8700216666985',
#  '3014230002366',
#  '3178041302159',
#  '7909189004980',
#  '3350031756801',
#  '3014230560033',
#  '8032274060734',
#  '4103040302014',
#  '8710447211052',
#  '96106617',
#  '0735745796207',
#  '3661434005879',
#  '5412533010411',
#  '75027537',
#  '8720181132391',
#  '8004395126217',
#  '4005808780969',
#  '7798130375404',
#  '8001090346865',
#  '24503228',
#  '0882381017996',
#  '7232726143058',
#  '3245678589830',
#  '3517360017076',
#  '8904417317282',
#  '4058172879609',
#  '4056489431084',
#  '3600550806045',
#  '3596710520565',
#  '3607342221208',
#  '8717644323083',
#  '3178040680876',
#  '3564700045305',
#  '0835374001144',
#  '4008233161327',
#  '3574661169392',
#  '3760155210255',
#  '8710447249017',
#  '42283393',
#  '0764302211068',
#  '3450970016711',
#  '3564700746851',
#  '3504105028183',
#  '4045612006602',
#  '3564700734353',
#  '4021457637591',
#  '8002295084132',
#  '3560070897513',
#  '8999999025007',
#  '3433422408586',
#  '3800038932369',
#  '3538394000186',
#  '3600521625262',
#  '8712100987021',
#  '0717334136052',
#  '5025452000601',
#  '8720181683329',
#  '0855275007106',
#  '0771058104940',
#  '8700216412926',
#  '3574661365305',
#  '3770013052118',
#  '4005808920518',
#  '7630028604046',
#  '8001090047861',
#  '70117011',
#  '5038483364345',
#  '5025416030675',
#  '3245678127377',
#  '3600542552981',
#  '8431876282337',
#  '4511413519479',
#  '4550512979524',
#  '3245678589854',
#  '3564700718445',
#  '3284410014933',
#  '4066447106404',
#  '8437014661880',
#  '8906038786416',
#  '0735745796153',
#  '5033102916523',
#  '42420125',
#  '4001638098090',
#  '8480017093837',
#  '3760214630178',
#  '3401360215801',
#  '3282779178624',
#  '5060209110165',
#  '7500326319822',
#  '3770002587065',
#  '3600551146041',
#  '8435064548014',
#  '0871760007550',
#  '3600522862413',
#  '3700593601574',
#  '3600550231830',
#  '0667557016528',
#  '0637913614354',
#  '3600523310524',
#  '3450970094504',
#  '8901030971921',
#  '3574661578224',
#  '3282770074161',
#  '3660005289595',
#  '3574661464978',
#  '4015600723644',
#  '3600550752373',
#  '5410091701857',
#  '3380380072727',
#  '3329310002120',
#  '3386460008747',
#  '3600542130790',
#  '3770018286150',
#  '8720181297700',
#  '8480000758156',
#  '3600523583331',
#  '3251248047204',
#  '0735745796023',
#  '3661434004704',
#  '3760020737337',
#  '4005900485458',
#  '3245678561881',
#  '3245678599600',
#  '5054563040480',
#  '3222474365301',
#  '7509552817355',
#  '8006540956588',
#  '4015000977579',
#  '3605972076168',
#  '3660005811031',
#  '2000000005963',
#  '3662076001243',
#  '3700578700452',
#  '3616302463893',
#  '7618900912205',
#  '8719134155051',
#  '3264680010491',
#  '3283950910255',
#  '4311501453018',
#  '4058172024382',
#  '20344863',
#  '3700970204152',
#  '0811913015209',
#  '8714789880525',
#  '3560070860517',
#  '3058320020014',
#  '4005808613380',
#  '3346470610415',
#  '3401597601613',
#  '3549620007039',
#  '0745114958075',
#  '8851932411394',
#  '0682223020111',
#  '4056489254805',
#  '8414227690005',
#  '3245678612583',
#  '3600550769180',
#  '3600550560107',
#  '8711700544078',
#  '0853036002285',
#  '4059729394521',
#  '4061458121651',
#  '3760001762723',
#  '8717163640708',
#  '0792734300265',
#  '3660005418643',
#  '3770002587058',
#  '3660005727226',
#  '0808124111639',
#  '3596710517077',
#  '3560070881192',
#  '42424536',
#  '8809625870096',
#  '4305615407609',
#  '7630028631127',
#  '3518646213014',
#  '8480000711199',
#  '3574661154008',
#  '8999999025014',
#  '8714789514635',
#  '3286011149144',
#  '3256987458373',
#  '3273818840121',
#  '3560070965977',
#  '3282779062671',
#  '3596204358520',
#  '3518646126970',
#  '3600522632641',
#  '3701194501669',
#  '2200215279682',
#  '4017512149819',
#  '3660005648712',
#  '5701092112521',
#  '5012251010672',
#  '3517360001303',
#  '3010351760116',
#  '3600550046571',
#  '4005900127280',
#  '7313272148213',
#  '8435255206174',
#  '3600542032551',
#  '2000000002894',
#  '3564700701058',
#  '4260486330213',
#  '4015001005653',
#  '3600523216253',
#  '4305615566290',
#  '4015600733810',
#  '3517360016079',
#  '3760100193589',
#  '3450970147576',
#  '3253581258743',
#  '5053526263492',
#  '3600542070898',
#  '3489940249705',
#  '0822142250668',
#  '3380810197396',
#  '8717163629079',
#  '3600531606534',
#  '3600550564075',
#  '3600522401032',
#  '3178041648585',
#  '4894532923496',
#  '7804955003672',
#  '8718114642871',
#  '87343588',
#  '4006000132242',
#  '4021457655137',
#  '8431876286519',
#  '0732953185045',
#  '26047935',
#  '2000000003469',
#  '4068134108159',
#  '8720181022708',
#  '3760368740730',
#  '42218944',
#  '6922275510043',
#  '4025089073703',
#  '4005900644107',
#  '3660005309774',
#  '8132100143096',
#  '8906036217684',
#  '8480000229311',
#  '4058172336591',
#  '4015100723885',
#  '4036581526680',
#  '7640183490156',
#  '3245678671283',
#  '4021457629084',
#  '4058172755026',
#  '7310610017590',
#  '4008233148182',
#  '59082873',
#  '3537090017412',
#  '4630061872023',
#  '3600523827787',
#  '3574661193175',
#  '3466762106225',
#  '3574661065427',
#  '8001090223623',
#  '3600551020457',
#  '3660005819211',
#  '8422410178940',
#  '3574661657486',
#  '8431876282139',
#  '50297627',
#  '5060176674868',
#  '3600523500284',
#  '8720181079177',
#  '8719326786568',
#  '33333366',
#  '4003583176311',
#  '3560070902880',
#  '4084500870772',
#  '3600530803873',
#  '8017331097106',
#  '30176171',
#  '4640145087519',
#  '3245678670743',
#  '4066447072068',
#  '3283950040075',
#  '8717333740801',
#  '4045612000099',
#  '0785364010253',
#  '5013965788055',
#  '3600550817584',
#  '3600551072074',
#  '4005900623553',
#  '4305615610368',
#  '4015600869236',
#  '8719281988502',
#  '3560070630899',
#  '36637027',
#  '3474630478244',
#  '3610340634185',
#  '3574661250335',
#  '7896085873270',
#  '8901571004096',
#  '8431876279627',
#  '8714789999890',
#  '3337875543248',
#  '3245678622780',
#  '7640183490323',
#  '3612623166239',
#  '3600550312454',
#  '5011321594388',
#  '3760095250328',
#  '0843536108266',
#  '3474630643161',
#  '7898587762380',
#  '4033981732079',
#  '3600550098228',
#  '4103040019899',
#  '8410412190077',
#  '3532662000847',
#  '3564700117187',
#  '0870446304839',
#  '3282770073676',
#  '5028197252472',
#  '8437016638361',
#  '9331137019216',
#  '4015400636649',
#  '7630028622606',
#  '0609408012228',
#  '5098928123319',
#  '3286010040176',
#  '3600523503292',
#  '3600541887930',
#  '3700216252688',
#  '9000101610352',
#  '3600540258564',
#  '7922470515323',
#  '3600521311479',
#  '3760089421154',
#  '4058172456923',
#  '0840044707011',
#  '3380380000713',
#  '7509552910124',
#  '3574661411545',
#  '3560070159024',
#  '8718215721246',
#  '3760100682717',
#  '8710847977770',
#  '4009800001008',
#  '4305615458977',
#  '3245678144701',
#  '3574661059099',
#  '8717644521021',
#  '8720181133015',
#  '3760349310594',
#  '7509546669663',
#  '8410436433624',
#  '3337875201360',
#  '3574661137292',
#  '8411047149089',
#  '3504105028428',
#  '8720289261542',
#  '3215666810048',
#  '3380390901154',
#  '3545230141347',
#  '8710447328095',
#  '4001638500029',
#  '8711700965002',
#  '3574660724226',
#  '24008938',
#  '40067353',
#  '7798140256762',
#  '3245678152508',
#  '4005900757968',
#  '8809370696286',
#  '7501039701553',
#  '4260004142311',
#  '3760098405480',
#  '8431876266382',
#  '5010724527481',
#  '3662361003228',
#  '3474630621206',
#  '4005900666031',
#  '3760099594763',
#  '3251248047624',
#  '4005900485243',
#  '7898085945001',
#  '5033102905022',
#  '3346470131408',
#  '5709954014297',
#  '7500435012140',
#  '3014230002229',
#  '8718951666306',
#  '7630028615509',
#  '3140100143096',
#  '3574660282719',
#  '3560070631797',
#  '3607345265018',
#  '4744183016200',
#  '8710447365649',
#  '8710908315428',
#  '7350069280022',
#  '4260378042934',
#  '0606345805906',
#  '5412339103591',
#  '3564700685174',
#  '8480017040794',
#  '5054563010650',
#  '4005900570956',
#  '8710522644027',
#  '3560070218608',
#  '3660005238234',
#  '3504105025793',
#  '8858890211219',
#  '8710522644003',
#  '8714789970486',
#  '80803591',
#  '3600523939008',
#  '4058172320569',
#  '07924316',
#  '8697420539887',
#  '3489940049251',
#  '3245678045718',
#  '0640986009033',
#  '4005900136688',
#  '0628634754115',
#  '3596710497553',
#  '20057060',
#  '7891010026844',
#  '7702018462773',
#  '42389149',
#  '3282779028394',
#  '8016825970642',
#  '0671635726599',
#  '3140700780868',
#  '3596206227794',
#  '3574661099224',
#  '5703147060986',
#  '7501026007101',
#  '0665124561235',
#  '3264680004285',
#  '3600550933536',
#  '3660005315799',
#  '4015400833581',
#  '30173378',
#  '8720181117367',
#  '4058172309274',
#  '5060305162365',
#  '5060356734214',
#  '3518646126581',
#  '2000000001344',
#  '3331849000041',
#  '4009800006164',
#  '3660005870281',
#  '0893400002084',
#  '5000167301250',
#  '7611916001420',
#  '3245678627150',
#  '8411047102558',
#  '3610340010279',
#  '3474394100009',
#  '3350031992612',
#  '3600541698482',
#  '8030243024046',
#  '3380380058578',
#  '3600523352852',
#  '5099821001414',
#  ...}

# %% [markdown]
# **2. Assegnazione pesi ai brand_segment.**
#
# Il sistema di suggerimento tiene conto del segmento di mercato e pesa la similarità in base ad esso.
# Prodotti dello stesso segmento avranno peso maggiore.

# %%
SEGMENT_SIMILARITY = {
    ('middle', 'middle'): 0.7,
    ('mass_market', 'mass_market'): 0.7,
    ('luxury', 'luxury'): 0.7,

    ('mass_market', 'middle'): 0.5,
    ('middle', 'mass_market'): 0.5,

    ('mass_market', 'luxury'): 0.3,
    ('luxury', 'mass_market'): 0.3,

    ('middle', 'luxury'): 0.5,
    ('luxury', 'middle'): 0.5
}

# %% [markdown]
# **3. Creazione dell'array di similarità 1xK.**
#
# Per il brand non uso una cosine similarity, ma una funzione deterministica basata su regole di business che tengono conto sia dell’identità del brand sia del segmento di mercato.
#
# Il sistema applica un hard filter sulla categoria per ridurre lo spazio di ricerca e garantire coerenza semantica, e successivamente calcola una similarità pesata basata su ingredienti e su regole di brand e segmento.

# %%
def brand_segment_similarity_1xK(
    query_product_id,
    df,
    category_col='macro_category',
    segment_col='brand_segment'
):
    query_product_id = str(query_product_id)

    if query_product_id not in df['code'].values:
        raise ValueError("Codice prodotto non trovato")

    query_row = df[df['code'] == query_product_id].iloc[0]
    query_category = query_row[category_col]
    query_brand = query_row['brand_name']
    query_segment = query_row[segment_col]

    # Filtro hard: stessa categoria -> ricerca tra prodotti della stessa categoria
    df_filtered = df[df[category_col] == query_category].copy()
    df_filtered = df_filtered[df_filtered['code'] != query_product_id]
    #filtro per evitare che restituisca lo stesso prodotto
    df_filtered['query_brand_name'] = query_brand

    similarities = []

    for _, row in df_filtered.iterrows():
        if row['brand_name'] == query_brand:
            similarities.append(1.0)#se il prodotto appartiene allo stesso brand avrà similarità massima
        else:
            pair = (query_segment, row[segment_col]) #altrimenti considera il segmento di mercato
            similarities.append(SEGMENT_SIMILARITY.get(pair, 0.0))
    df_filtered['similarity'] = similarities
    return np.array(similarities), df_filtered

# %% [markdown]
# 4. Applicazione della funzione e creazione dell'aray one-time a partire dal prodotto

# %%
query_id = input('Inserisci il codice del prodotto: ')

brand_sim = brand_segment_similarity_1xK(query_id, df)
#non ottengo una matrice di similarità NXN, ma un array 1xK:
#cioè la similarità del prodotto query rispetto a tutti gli altri prodotti della stessa categoria



#brand_sim è una tupla: il primo elemento è l'array 1xK, il secondo elemento è il dataframe con i prodotti candidati
#brand_sim == (similarity_array, df_filtered).
#la tupla serve a sapere a quali prodotti mi riferisco
brand_sim_array, df_brand_candidates = brand_sim

# %%
brand_sim_array[:10] #vedo i primi dieci valori di similarità
# Out:
# array([0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3, 0.3])

# %%
df_brand_candidates.sort_values('similarity', ascending= False).head(10) #vedo i primi dieci candidati
# Out:
#                 code             product_name      brand_name brand_segment  \
# 10873  3401399693984     mousse demaquillante         filorga        luxury
# 10868  3401561313061               bb perfect         filorga        luxury
# 10870  3401360156456             ncef essence         filorga        luxury
# 11990  3346470122000                 shalimar        guerlain        luxury
# 13265  6291106031454      desert dusk palette     huda beauty        luxury
# 3098     25514145003               matte clay        beesmade        luxury
# 14343  3474630477056          elixir k ultime       kerastase        luxury
# 7719   8004608242147                     momo         davines        luxury
# 5566   3348900012189               fahrenheit  christian dior        luxury
# 12159  8809653230930  pore cleansing balm aha         hanskin        luxury
#
#       macro_category query_brand_name  similarity
# 10873          Other          filorga         1.0
# 10868          Other          filorga         1.0
# 10870          Other          filorga         1.0
# 11990          Other          filorga         0.7
# 13265          Other          filorga         0.7
# 3098           Other          filorga         0.7
# 14343          Other          filorga         0.7
# 7719           Other          filorga         0.7
# 5566           Other          filorga         0.7
# 12159          Other          filorga         0.7

# %% [markdown]
# 5. Con questa funzione si trovano i prodotti più simili a un prodotto dato, guardando solo gli ingredienti. Prima limita il confronto ai prodotti della stessa categoria, così il confronto ha senso.
# Poi confronta gli ingredienti del prodotto scelto con quelli degli altri e dice quanto si assomigliano, usando un punteggio numerico.

# %%
#pulizia per esclusione ingredienti che potrebbero compromettere il corretto
#calcolo della similarità
EXCLUDE_INGREDIENTS = {
    'aqua', 'water', 'parfum', 'fragrance',
    'ci', 'color', 'colour',
    'sodium chloride'
}

def clean_ingredients(ing_string):
    ing = [
        i.strip().lower()
        for i in ing_string.split(',')
        if len(i.strip()) > 2
    ]
    ing = [
        i for i in ing
        if not any(x in i for x in EXCLUDE_INGREDIENTS)
        and not i.startswith('ci ')
    ]
    return list(set(ing))

# %%
df_finale['ingredients_list'] = df_finale['ingredients'].apply(clean_ingredients)

df_finale[['ingredients', 'ingredients_list']].head(10)
# Out:
#                                          ingredients  \
# 0  Arnica Montana, Avoid Contact With Eyes, Burit...
# 1                                                Oil
# 2  Added Sugarss, Colorings, Cr 6Ad, Croydon, Lac...
# 3                                                Oil
# 4                Lilium Candidum Flower Extract, Oil
# 5  Allantoin, Aloe Barbadensis Leaf Juice, Benzoi...
# 6  Coco-Glucoside, Decyl Glucoside, Glycerin, Gly...
# 7                       Lawsonia Inermis Leaf Powder
# 8                     Natural Calcium Bentonite Clay
# 9  Cellulose Gum, Citric Acid, Cocamidopropyl Bet...
#
#                                     ingredients_list
# 0  [mucous, buriti oil, menthol, tocopherol, phen...
# 1                                              [oil]
# 2  [cr 6ad, preservatives, added sugarss, croydon...
# 3                                              [oil]
# 4              [oil, lilium candidum flower extract]
# 5  [aloe barbadensis leaf juice, phenoxyethanol, ...
# 6  [sodium cocoamphoacetate, sodium cocoyl glutam...
# 7                     [lawsonia inermis leaf powder]
# 8                                                 []
# 9  [sodium saccharin, tetrasodium pyrophosphate, ...

# %%
def jaccard_similarity(set_a, set_b):
    if not set_a or not set_b:
        return 0.0
    return len(set_a & set_b) / len(set_a | set_b)

# %%
def ingredient_similarity_1xK(
    query_product_id,
    df_finale,
    category_col='macro_category'
):
    query_product_id = str(query_product_id)

    if query_product_id not in df_finale['code'].values:
        raise ValueError("Codice prodotto non trovato")

    query_row = df_finale[df_finale['code'] == query_product_id].iloc[0]
    query_category = query_row[category_col]
    query_ing = set(query_row['ingredients_list'])

    # Filtro hard: stessa categoria
    df_filtered = df_finale[df_finale[category_col] == query_category].copy()
    df_filtered = df_filtered[df_filtered['code'] != query_product_id]

    print(f"Trovati {len(df_filtered)} prodotti nella stessa categoria")

    similarities = []

    for _, row in df_filtered.iterrows():
        sim = jaccard_similarity(
            query_ing,
            set(row['ingredients_list'])
        )
        similarities.append(sim)

    return np.array(similarities), df_filtered

# %%
ing_sim_array, df_ing_candidates = ingredient_similarity_1xK(query_id, df_finale)

ing_sim_array[:10]
# Out:
# Trovati 5582 prodotti nella stessa categoria
# array([0.02409639, 0.        , 0.02531646, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.07228916, 0.        ])

# %%
#aggiunta similarità e is_query per vedere quali sono i prod raccomandati e 
#qual è il prodotto originale cercato
df_ing_candidates_temp = df_ing_candidates[df_ing_candidates['code'] != query_id].copy()
df_ing_candidates_temp['ing_sim'] = ing_sim_array
df_ing_candidates_temp['is_query'] = False
df_ing_candidates_temp = df_ing_candidates_temp.sort_values(by='ing_sim', ascending=False).reset_index(drop=True)


df_query_ing = df_finale[df_finale['code'] == query_id].copy()
df_query_ing['ing_sim'] = 1.0        # similarità massima con se stesso
df_query_ing['is_query'] = True

df_ing_candidates = pd.concat(
    [df_query_ing, df_ing_candidates_temp],
    ignore_index=True
)

df_ing_candidates.head(10)
# Out:
#             code                                product_name macro_category  \
# 0  3401351102882                   Filorga Hydra Filler 50ML          Other
# 1  0769915190731           Natural Moisturizing Factors + HA          Other
# 2  8437018454099                               averac caviar          Other
# 3  0850056933285                         Leave In - Numéro 5          Other
# 4  0850155008532                              Beauty insider          Other
# 5  0769915150100  Multi-Molecular Hyaluronic Complex (MMHC2)          Other
# 6  3700454229541                        Structu'r'temps jour          Other
# 7  2021092899998                   Hello Mirror guess my age          Other
# 8  3700914601962                           Princesse de jour          Other
# 9  5904858674268              Odżywka do włosów zniszczonych          Other
#
#                                          ingredients  \
# 0  1, 2-Hexanediol, Alanine, Aminobutyric Acid, A...
# 1  Alanine, Allantoin, Arginine, Aspartic Acid, C...
# 2  Arginine, Ascorbyl Palmitate, Aspartic Acid, B...
# 3  Alanine, Algin, Arginine, Aspartic Acid, Astro...
# 4  1, 2-Hexanediol, Acetyl Glutamine, Alanine, Al...
# 5  1, 2-Hexanediol, Alanine, Algae Extract, Argin...
# 6  Acmella Oleracea Extract, Alpha-Isomethyl Iono...
# 7  Alpha-Isomethyl Lonone, Anhydroxylitol, Arachi...
# 8  Algae Extract, Arachidyl Alcohol, Arachidyl Gl...
# 9  Alanine, Arginine, Aspartic Acid, Behentrimoni...
#
#                                     ingredients_list   ing_sim  is_query
# 0  [phenylalanine, asparagine, glucose, sodium gl...  1.000000      True
# 1  [cetyl alcohol, phenylalanine, glucose, trehal...  0.157895     False
# 2  [caviar extract, phenylalanine, carragenan pul...  0.141593     False
# 3  [cetyl alcohol, fructooligosaccharides, phenyl...  0.125984     False
# 4  [phenylalanine, aloe barbadensis leaf extract,...  0.115702     False
# 5  [phenylalanine, gallyl glucoside, phenoxyethan...  0.115044     False
# 6  [potassium sorbate, ethylhexyl palmitate, cycl...  0.112245     False
# 7  [glucose, butylphenyl methylpropional, behenyl...  0.111111     False
# 8  [cetery alcohol, behenyl alcohol, phenoxyethan...  0.109890     False
# 9  [cetrimonium chloride, laminaria digitata extr...  0.107527     False

# %%
query_product_ingredients = set(
    df_finale[df_finale['code'] == query_id]['ingredients_list'].iloc[0]
)

def get_common_ingredients(candidate_ingredients):
    return list(query_product_ingredients.intersection(set(candidate_ingredients)))

df_ing_candidates['common_ingr'] = df_ing_candidates['ingredients_list'].apply(get_common_ingredients)

df_ing_candidates[['code', 'product_name', 'ingredients_list', 'common_ingr']].head(10)
# Out:
#             code                                product_name  \
# 0  3401351102882                   Filorga Hydra Filler 50ML
# 1  0769915190731           Natural Moisturizing Factors + HA
# 2  8437018454099                               averac caviar
# 3  0850056933285                         Leave In - Numéro 5
# 4  0850155008532                              Beauty insider
# 5  0769915150100  Multi-Molecular Hyaluronic Complex (MMHC2)
# 6  3700454229541                        Structu'r'temps jour
# 7  2021092899998                   Hello Mirror guess my age
# 8  3700914601962                           Princesse de jour
# 9  5904858674268              Odżywka do włosów zniszczonych
#
#                                     ingredients_list  \
# 0  [phenylalanine, asparagine, glucose, sodium gl...
# 1  [cetyl alcohol, phenylalanine, glucose, trehal...
# 2  [caviar extract, phenylalanine, carragenan pul...
# 3  [cetyl alcohol, fructooligosaccharides, phenyl...
# 4  [phenylalanine, aloe barbadensis leaf extract,...
# 5  [phenylalanine, gallyl glucoside, phenoxyethan...
# 6  [potassium sorbate, ethylhexyl palmitate, cycl...
# 7  [glucose, butylphenyl methylpropional, behenyl...
# 8  [cetery alcohol, behenyl alcohol, phenoxyethan...
# 9  [cetrimonium chloride, laminaria digitata extr...
#
#                                          common_ingr
# 0  [phenylalanine, asparagine, glucose, sodium gl...
# 1  [phenylalanine, valine, glucose, alanine, chlo...
# 2  [phenylalanine, tyrosine, valine, chlorphenesi...
# 3  [phenylalanine, valine, alanine, sodium hyalur...
# 4  [phenylalanine, valine, 2-hexanediol, alanine,...
# 5  [phenylalanine, valine, 2-hexanediol, alanine,...
# 6  [chlorphenesin, dimethicone, sodium hyaluronat...
# 7  [glucose, behenyl alcohol, sodium hyaluronate,...
# 8  [chlorphenesin, behenyl alcohol, sodium hyalur...
# 9  [valine, alanine, potassium sorbate, glycerin,...

# %%
ing_sim_array[:10]
# Out:
# array([0.02409639, 0.        , 0.02531646, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.07228916, 0.        ])

# %%
df_ing_candidates.head(10)
# Out:
#             code                                product_name macro_category  \
# 0  3401351102882                   Filorga Hydra Filler 50ML          Other
# 1  0769915190731           Natural Moisturizing Factors + HA          Other
# 2  8437018454099                               averac caviar          Other
# 3  0850056933285                         Leave In - Numéro 5          Other
# 4  0850155008532                              Beauty insider          Other
# 5  0769915150100  Multi-Molecular Hyaluronic Complex (MMHC2)          Other
# 6  3700454229541                        Structu'r'temps jour          Other
# 7  2021092899998                   Hello Mirror guess my age          Other
# 8  3700914601962                           Princesse de jour          Other
# 9  5904858674268              Odżywka do włosów zniszczonych          Other
#
#                                          ingredients  \
# 0  1, 2-Hexanediol, Alanine, Aminobutyric Acid, A...
# 1  Alanine, Allantoin, Arginine, Aspartic Acid, C...
# 2  Arginine, Ascorbyl Palmitate, Aspartic Acid, B...
# 3  Alanine, Algin, Arginine, Aspartic Acid, Astro...
# 4  1, 2-Hexanediol, Acetyl Glutamine, Alanine, Al...
# 5  1, 2-Hexanediol, Alanine, Algae Extract, Argin...
# 6  Acmella Oleracea Extract, Alpha-Isomethyl Iono...
# 7  Alpha-Isomethyl Lonone, Anhydroxylitol, Arachi...
# 8  Algae Extract, Arachidyl Alcohol, Arachidyl Gl...
# 9  Alanine, Arginine, Aspartic Acid, Behentrimoni...
#
#                                     ingredients_list   ing_sim  is_query  \
# 0  [phenylalanine, asparagine, glucose, sodium gl...  1.000000      True
# 1  [cetyl alcohol, phenylalanine, glucose, trehal...  0.157895     False
# 2  [caviar extract, phenylalanine, carragenan pul...  0.141593     False
# 3  [cetyl alcohol, fructooligosaccharides, phenyl...  0.125984     False
# 4  [phenylalanine, aloe barbadensis leaf extract,...  0.115702     False
# 5  [phenylalanine, gallyl glucoside, phenoxyethan...  0.115044     False
# 6  [potassium sorbate, ethylhexyl palmitate, cycl...  0.112245     False
# 7  [glucose, butylphenyl methylpropional, behenyl...  0.111111     False
# 8  [cetery alcohol, behenyl alcohol, phenoxyethan...  0.109890     False
# 9  [cetrimonium chloride, laminaria digitata extr...  0.107527     False
#
#                                          common_ingr
# 0  [phenylalanine, asparagine, glucose, sodium gl...
# 1  [phenylalanine, valine, glucose, alanine, chlo...
# 2  [phenylalanine, tyrosine, valine, chlorphenesi...
# 3  [phenylalanine, valine, alanine, sodium hyalur...
# 4  [phenylalanine, valine, 2-hexanediol, alanine,...
# 5  [phenylalanine, valine, 2-hexanediol, alanine,...
# 6  [chlorphenesin, dimethicone, sodium hyaluronat...
# 7  [glucose, behenyl alcohol, sodium hyaluronate,...
# 8  [chlorphenesin, behenyl alcohol, sodium hyalur...
# 9  [valine, alanine, potassium sorbate, glycerin,...

# %% [markdown]
# **5. Indicizzazione su codice prodotto**
#
# Costruzione nuovo DF: unione dei due dataframe sul codice prodotto al fine del calcolo della similarità finale.

# %%
df_ing= df_ing_candidates[['code', 'ing_sim']].copy()

df_brand = df_brand_candidates[['code']].copy()
df_brand['brand_sim'] = brand_sim_array

#allineo la similarità
df_merged = df_ing.merge(
    df_brand,
    on='code',
    how='inner'
)

# %%
#check per verificare che l'allineamento è corretto
assert len(df_merged) > 0
assert df_merged['code'].is_unique

df_merged.head()
# Out:
#             code   ing_sim  brand_sim
# 0  0769915190731  0.157895        0.3
# 1  0850056933285  0.125984        0.3
# 2  0850155008532  0.115702        0.7
# 3  0769915150100  0.115044        0.7
# 4  3700454229541  0.112245        0.5

# %% [markdown]
# **6. Calcolo della similarità finale**
#
# Gli ingredienti hanno peso maggiore nel determinare il prodotto più simile (0.8). I brand hanno peso minore (0.2).

# %%
df_merged['final_similarity'] = (
    0.8 * df_merged['ing_sim'] +
    0.2 * df_merged['brand_sim']
)

# %% [markdown]
# **6. Costruzione dataframe per la visualizzazione del prodotto più simile**

# %%
query_product_name = (
    df.loc[df['code'] == query_id, 'product_name']
    .iloc[0]
)
risultato = pd.DataFrame({
    'query_product_id': query_id,
    'query_product_name': query_product_name,
    'recommended_product_id': df_merged['code'],
    'final_similarity_score': df_merged['final_similarity'],

})

#ordino i prodotti per suggerire il prodotto più simile
risultato = risultato.sort_values(
    by='final_similarity_score',
    ascending=False
).reset_index(drop=True)

risultato['rank'] = risultato.index + 1

# arricchimento informativo (nome, brand, segmento)
risultato = risultato.merge(
    df[['code', 'product_name', 'brand_name', 'brand_segment']],
    left_on='recommended_product_id',
    right_on='code',
    how='left'
).drop(columns='code')

risultato = risultato[
    [
        'rank',
        'query_product_id',
        'query_product_name',
        'recommended_product_id',
        'product_name',
        'brand_name',
        'brand_segment',
        'final_similarity_score'
    ]
]

risultato.head(10)
# Out:
#    rank query_product_id         query_product_name recommended_product_id  \
# 0     1    3401351102882  filorga hydra filler 50ml          0850155008532
# 1     2    3401351102882  filorga hydra filler 50ml          0769915150100
# 2     3    3401351102882  filorga hydra filler 50ml          0651986701308
# 3     4    3401351102882  filorga hydra filler 50ml          8500033101122
# 4     5    3401351102882  filorga hydra filler 50ml          3760096762141
# 5     6    3401351102882  filorga hydra filler 50ml          0641628005208
# 6     7    3401351102882  filorga hydra filler 50ml          7640114110887
# 7     8    3401351102882  filorga hydra filler 50ml          3700454229541
# 8     9    3401351102882  filorga hydra filler 50ml          0773602657070
# 9    10    3401351102882  filorga hydra filler 50ml          3337871328795
#
#                                         product_name           brand_name  \
# 0                                     beauty insider              sephora
# 1           multi molecular hyaluronic complex mmhc2                 niod
# 2                                      born this way  too faced cosmetics
# 3                                  tula bright start                 tula
# 4                                        baume divin             qiriness
# 5                    dynamic resurfacing facial wash               elemis
# 6                                    le wrap exfolys             qiriness
# 7                               structu r temps jour              auriege
# 8  studio radiance 24hr luminous lift concealer nc11                  mac
# 9           liftactiv supreme peaux normales a mixte                vichy
#
#   brand_segment  final_similarity_score
# 0        luxury                0.232562
# 1        luxury                0.232035
# 2        luxury                0.208085
# 3        luxury                0.206667
# 4        luxury                0.203636
# 5        luxury                0.196000
# 6        luxury                0.191064
# 7        middle                0.189796
# 8        luxury                0.189123
# 9        luxury                0.188980
