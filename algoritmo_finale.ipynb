# %% [markdown]
# #Sistema di raccomandazione
# Il sistema implementa un approccio di raccomandazione one-time, evitando la costruzione di matrici di similarità NxN. Applica un filtro hard sulla categoria e combina una similarità basata su ingredienti con una funzione deterministica di brand e segmento, pesate rispettivamente 0.8 e 0.2.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) Importo il df e creo un nuovo df con le colonne d'interesse

# %%
df = pd.read_csv("brand_categoria.csv",dtype={"code": str})

df = df[['code', 'product_name','brand_name', 'brand_segment','macro_category']].copy()
df['code'] = df['code'].astype(str)
df['product_name'] = df['product_name'].astype(str)
df['brand_name'] = df['brand_name'].astype(str)
df['brand_segment'] = df['brand_segment'].astype(str)
df['macro_category'] = df['macro_category'].astype(str)


df.head(20)
# Out:
#              code                                       product_name  \
# 0   5013965698897                                                  1
# 1     88582000939                                                  2
# 2   0650240025396                              zan zusi b b flash 30
# 3   3560070084074                                     deo men marine
# 4   6134598000044                            savon liquide main life
# 5   5943044010046                                         gerocossen
# 6        20546472                                               cien
# 7   3700216252688                                 glycerine vegetale
# 8   8859423200212                                             habino
# 9   6130460000747                                                nan
# 10  5600380895293                                l citrulline malate
# 11  3574661599281                       johnson baby wipes 2yrs prod
# 12  3600523709649                               elseve rapid restore
# 13  8710871392327                                     balsam tissues
# 14  0850028447840                                          full mega
# 15  0633911616277                                                  1
# 16  0716237185600  frizz be gone leave in conditioning styling el...
# 17  8718481351000                                          aloe vera
# 18  0740985223901                                      sentry senior
# 19  8436567350524                               night recovery cream
#
#         brand_name brand_segment macro_category
# 0                1   mass_market          Other
# 1                1   mass_market          Other
# 2                1   mass_market          Other
# 3   1 de carrefour   mass_market     Deodorants
# 4           100 da   mass_market        Hygiene
# 5               12   mass_market          Other
# 6               12   mass_market          Other
# 7       123gelules   mass_market          Other
# 8            13000   mass_market          Other
# 9            150da   mass_market          Other
# 10            150g   mass_market          Other
# 11         168 pcs   mass_market      Baby_Care
# 12          180 ml   mass_market          Other
# 13        1debeste   mass_market          Other
# 14       1st phorm   mass_market          Other
# 15               2   mass_market          Other
# 16          2 chic   mass_market      Hair_Care
# 17            2025   mass_market          Other
# 18      21 century   mass_market          Other
# 19          226ers   mass_market      Face_Care

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_ing = pd.read_csv("ingr_cat.csv",dtype={"code": str})


df_ing['code'] = df_ing['code'].astype(str)
df_ing['product_name'] = df_ing['product_name'].astype(str)
df_ing['macro_category'] = df_ing['macro_category'].astype(str)
df_ing['inci_name'] = df_ing['inci_name'].astype(str)

df_finale = (
    df_ing
    .groupby(['code', 'product_name', 'macro_category'])['inci_name']
    .apply(lambda lst: ", ".join(sorted(set(lst))))
    .reset_index()
    .rename(columns={'inci_name': 'ingredients'}))

df_finale.head(20)
# Out:
#              code                               product_name macro_category  \
# 0        00000014                            Süßlupinen Mehl          Other
# 1        00000311                Huile végétale Amande douce           Oils
# 2        00000511                       pure collagène marin          Other
# 3        00000561                        Huile végétale coco           Oils
# 4        00000587                        Macérât huileux Lys           Oils
# 5        00000695                               olé olé Aloé          Other
# 6        00000859                               Base lavante         Makeup
# 7        00000905                             Henné d'Egypte          Other
# 8        00001277                        Indian Healing Clay          Other
# 9   0000160332625                         Colgate toothpaste        Hygiene
# 10       00001785  Nutricentials, day dream protective cream      Face_Care
# 11       00002337                            Base shampooing      Hair_Care
# 12       00002369                  Crème neutre désaltérante      Face_Care
# 13       00002631                    Herbal Aloe Concentrado          Other
# 14       00002698              Gel douche sorbet de verveine      Body_Care
# 15       00002708                 Base micellaire concentrée         Makeup
# 16       00002979           Coloration végétale henné cuivré          Other
# 17       00002980                        Henné châtain foncé          Other
# 18       00004019                   Soin neutre Lait végétal          Other
# 19       00006582     Jardins du monde Fleur de coton d'Inde          Other
#
#                                           ingredients
# 0   Arnica Montana, Avoid Contact With Eyes, Burit...
# 1                                                 Oil
# 2   Added Sugarss, Colorings, Cr 6Ad, Croydon, Lac...
# 3                                                 Oil
# 4                 Lilium Candidum Flower Extract, Oil
# 5   Allantoin, Aloe Barbadensis Leaf Juice, Benzoi...
# 6   Coco-Glucoside, Decyl Glucoside, Glycerin, Gly...
# 7                        Lawsonia Inermis Leaf Powder
# 8                      Natural Calcium Bentonite Clay
# 9   Cellulose Gum, Citric Acid, Cocamidopropyl Bet...
# 10  Ammonium Acryloyldimethyltauratevp Copolymer, ...
# 11  Arginine, Babassuamidopropyl Betaine, Coco-Glu...
# 12  Aloe Barbadensis Leaf Extract, Cetearyl Olivat...
# 13  1 Ppm, 13 G100 G, Cido Ctrico Anhidro, Sabor N...
# 14  Benzyl Alcohol, Ci 75300, Citral, Coco-Glucosi...
# 15  Biosaccharide Gum-1, Glyceril Caprylate, Glyce...
# 16  Aloe Barbadensis Leaf Powder, Curcuma Longa Ro...
# 17  Curcuma Longa Root Powder, Emblica Officinalis...
# 18  Butyrospermum Parkii Butter, C10-18 Triglyceri...
# 19  Aluminum Chlorohydrate, Fragrance, Gossypium H...

# %% [markdown]
# **2. Assegnazione pesi ai brand_segment.**
#
# Il sistema di suggerimento tiene conto del segmento di mercato e pesa la similarità in base ad esso.
# Prodotti dello stesso segmento avranno peso maggiore.

# %%
SEGMENT_SIMILARITY = {
    ('middle', 'middle'): 0.7,
    ('mass_market', 'mass_market'): 0.7,
    ('luxury', 'luxury'): 0.7,

    ('mass_market', 'middle'): 0.5,
    ('middle', 'mass_market'): 0.5,

    ('mass_market', 'luxury'): 0.3,
    ('luxury', 'mass_market'): 0.3,

    ('middle', 'luxury'): 0.5,
    ('luxury', 'middle'): 0.5
}

# %% [markdown]
# **3. Creazione dell'array di similarità 1xK.**
#
# Per il brand non uso una cosine similarity, ma una funzione deterministica basata su regole di business che tengono conto sia dell’identità del brand sia del segmento di mercato.
#
# Il sistema applica un hard filter sulla categoria per ridurre lo spazio di ricerca e garantire coerenza semantica, e successivamente calcola una similarità pesata basata su ingredienti e su regole di brand e segmento.

# %%
def brand_segment_similarity_1xK(
    query_product_id,
    df,
    category_col='macro_category',
    segment_col='brand_segment'
):
    query_product_id = str(query_product_id)

    if query_product_id not in df['code'].values:
        raise ValueError("Codice prodotto non trovato")

    query_row = df[df['code'] == query_product_id].iloc[0]
    query_category = query_row[category_col]
    query_brand = query_row['brand_name']
    query_segment = query_row[segment_col]

    # Filtro hard: stessa categoria -> ricerca tra prodotti della stessa categoria
    df_filtered = df[df[category_col] == query_category].copy()
    df_filtered = df_filtered[df_filtered['code'] != query_id]
    #filtro per evitare che restituisca lo stesso prodotto

    similarities = []

    for _, row in df_filtered.iterrows():
        if row['brand_name'] == query_brand:
            similarities.append(1.0)#se il prodotto appartiene allo stesso brand avrà similarità massima
        else:
            pair = (query_segment, row[segment_col]) #altrimenti considera il segmento di mercato
            similarities.append(SEGMENT_SIMILARITY.get(pair, 0.0))

    return np.array(similarities), df_filtered

# %% [markdown]
# 4. Applicazione della funzione e creazione dell'aray one-time a partire dal prodotto

# %%
query_id = input('Inserisci il codice del prodotto: ')

brand_sim = brand_segment_similarity_1xK(query_id, df)
#non ottengo una matrice di similarità NXN, ma un array 1xK:
#cioè la similarità del prodotto query rispetto a tutti gli altri prodotti della stessa categoria



#brand_sim è una tupla: il primo elemento è l'array 1xK, il secondo elemento è il dataframe con i prodotti candidati
#brand_sim == (similarity_array, df_filtered).
#la tupla serve a sapere a quali prodotti mi riferisco
brand_sim_array, df_brand_candidates = brand_sim
# Out:
# Inserisci il codice del prodotto: 8029513115935

# %%
brand_sim_array[:10] #vedo i primi dieci valori di similarità
# Out:
# array([0.7, 0.5, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7])

# %%
df_brand_candidates.head(10) #vedo i primi dieci candidati
# Out:
#              code                               product_name  \
# 4   6134598000044                    savon liquide main life
# 24    99482463069                          foaming hand soap
# 25    99482496517                      mint garden hand soap
# 28  4987176082152                                     oral b
# 37  4102968000415                                 dentifrice
# 58  3770018286228          dentifrice a croquer menthe douce
# 60  3770018286013      dentifrice arome menthe extra fraiche
# 61  3760346073027             dentifrice en pastilles fraise
# 62  3760346074611                     dentifrice en pastille
# 65  3770018286235  dentifrice a croquer menthe extra fraiche
#
#                 brand_name brand_segment macro_category
# 4                   100 da   mass_market        Hygiene
# 24         365 whole foods        middle        Hygiene
# 25  365 whole foods market   mass_market        Hygiene
# 28                3d white   mass_market        Hygiene
# 37                   50 ml   mass_market        Hygiene
# 58                900 care   mass_market        Hygiene
# 60                900 care   mass_market        Hygiene
# 61                900 care   mass_market        Hygiene
# 62                900 care   mass_market        Hygiene
# 65                900 care   mass_market        Hygiene

# %% [markdown]
# 5. Con questa funzione si trovano i prodotti più simili a un prodotto dato, guardando solo gli ingredienti. Prima limita il confronto ai prodotti della stessa categoria, così il confronto ha senso.
# Poi confronta gli ingredienti del prodotto scelto con quelli degli altri e dice quanto si assomigliano, usando un punteggio numerico.

# %%
def ingredient_similarity_1xK_detailed(
    query_product_id,
    df_finale,
    X_ing,      # matrice bag-of-words
    category_col='macro_category'
):
    query_product_id = str(query_product_id)

    if query_product_id not in df_finale['code'].values:
        raise ValueError("Codice prodotto non trovato")

    query_row = df_finale[df_finale['code'] == query_product_id].iloc[0]
    query_category = query_row[category_col]

    # Filtro hard: stessa categoria
    df_filtered = df_finale[df_finale[category_col] == query_category].copy()
    df_filtered = df_filtered[df_filtered['code'] != query_product_id]

    print(f"Trovati {len(df_filtered)} prodotti nella stessa categoria")

    idx_query = df_finale.index[df_finale['code'] == query_product_id][0]

    # Vettore query
    vec_query = X_ing[idx_query]

    # Vettori filtrati
    indices_filtered = df_filtered.index
    X_filtered = X_ing[indices_filtered]

    # Similarità coseno 1xK
    similarities = cosine_similarity(vec_query, X_filtered)[0]

    return np.array(similarities), df_filtered

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

vectorizer = CountVectorizer(token_pattern=r'[^,]+')
X_ing = vectorizer.fit_transform(df_finale['ingredients'])

# %%
query_id = input('Inserisci il codice del prodotto: ')
ing_sim = ingredient_similarity_1xK_detailed(query_id, df_finale, X_ing)
ing_sim_array, df_ing_candidates = ing_sim
# Out:
# Inserisci il codice del prodotto: 8029513115935
# Trovati 1457 prodotti nella stessa categoria

# %%
ing_sim_array[:10]
# Out:
# array([0.        , 0.11396058, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.25197632, 0.10482848])

# %%
df_ing_candidates.head(10)
# Out:
#               code                            product_name macro_category  \
# 9    0000160332625                      Colgate toothpaste        Hygiene
# 22   0000902980642                    Curasept colluttorio        Hygiene
# 26   0001182258268  Oral care dry mouth lozenges fruit mix        Hygiene
# 34        00014478                          Luminous white        Hygiene
# 36        00014647            Colgate sensitiva pro alivio        Hygiene
# 37        00014806                    Colgate Pasta Dental        Hygiene
# 52        00037541                     Ultimate Mouth Wash        Hygiene
# 74   0009253900004  burts beevfor kids fluoride toothpaste        Hygiene
# 94   0010486007004                        The Grandpa Soap        Hygiene
# 124  0011111377462                                Soap Bar        Hygiene
#
#                                            ingredients
# 9    Cellulose Gum, Citric Acid, Cocamidopropyl Bet...
# 22   Aroma, Ascorbic Cid, Chlorhexidine Digluconate...
# 26   Blue 1, Blue 2, Gum Arabic, Lime, Oil, Orange,...
# 34                   Benzyl Alcoholi Alcohol Benc0Lico
# 36   Aromasabor, Interrompa A5 Ote Nal, Kanthan Gum...
# 37   Aroma, Benzyl Alcohol, Cellulose Gum, Ci 77891...
# 52   900 500, Anethole, Citrus Paradisi Seed Extrac...
# 74   Carrageenan, Cut, Hydrated Silica, Or Missing ...
# 94   Glycerin, Pinus Palustris Wood Tar, Sodium Chl...
# 124  Cocamidopropyl Betaine, Dipropylene Glycol, La...

# %% [markdown]
# **5. Indicizzazione su codice prodotto**
#
# Costruzione nuovo DF: unione dei due dataframe sul codice prodotto al fine del calcolo della similarità finale.

# %%
df_ing = df_ing_candidates[['code']].copy()
df_ing['ing_sim'] = ing_sim_array

df_brand = df_brand_candidates[['code']].copy()
df_brand['brand_sim'] = brand_sim_array

#allineo la similarità
df_merged = df_ing.merge(
    df_brand,
    on='code',
    how='inner'
)

# %%
#check per verificare che l'allineamento è corretto
assert len(df_merged) > 0
assert df_merged['code'].is_unique

# %% [markdown]
# **6. Calcolo della similarità finale**
#
# Gli ingredienti hanno peso maggiore nel determinare il prodotto più simile (0.8). I brand hanno peso minore (0.2).

# %%
df_merged['final_similarity'] = (
    0.8 * df_merged['ing_sim'] +
    0.2 * df_merged['brand_sim']
)

# %% [markdown]
# **6. Costruzione dataframe per la visualizzazione del prodotto più simile**

# %%
query_product_name = (
    df.loc[df['code'] == query_id, 'product_name']
    .iloc[0]
)
risultato = pd.DataFrame({
    'query_product_id': query_id,
    'query_product_name': query_product_name,
    'recommended_product_id': df_merged['code'],
    'final_similarity_score': df_merged['final_similarity'],

})

#ordino i prodotti per suggerire il prodotto più simile
risultato = risultato.sort_values(
    by='final_similarity_score',
    ascending=False
).reset_index(drop=True)

risultato['rank'] = risultato.index + 1

# arricchimento informativo (nome, brand, segmento)
risultato = risultato.merge(
    df[['code', 'product_name', 'brand_name', 'brand_segment']],
    left_on='recommended_product_id',
    right_on='code',
    how='left'
).drop(columns='code')

risultato = risultato[
    [
        'rank',
        'query_product_id',
        'query_product_name',
        'recommended_product_id',
        'product_name',
        'brand_name',
        'brand_segment',
        'final_similarity_score'
    ]
]

risultato.head(10)
# Out:
#    rank query_product_id recommended_product_id  \
# 0     1    8029513115935          0628451857143
# 1     2    8029513115935          4056489294566
# 2     3    8029513115935          5701017418615
# 3     4    8029513115935               20827397
# 4     5    8029513115935          7072463113170
# 5     6    8029513115935          7090025533099
# 6     7    8029513115935          7311043009695
# 7     8    8029513115935          0732913229307
# 8     9    8029513115935          3256228666741
# 9    10    8029513115935          0829576020058
#
#                                       product_name             brand_name  \
# 0                                    savon a mains  the unscented company
# 1                            gentle pure hand soap                   cien
# 2                                        hand soap      sensitive for you
# 3                              sensitive hand soap                   cien
# 4   refill hand wash white tea verbena 500ml 1 stk          elle basic as
# 5  moisturising hand wash white tea verbena 500 ml          elle basic as
# 6                    hand soap 0 perfume colorants   mevolution sensitive
# 7                                  free clean soap     seventh generation
# 8       savon vegetal ressourcant peche jasmin bio                  u bio
# 9                      lemon mint liquid hand soap            ever spring
#
#   brand_segment  final_similarity_score
# 0   mass_market                0.595842
# 1   mass_market                0.543162
# 2   mass_market                0.522473
# 3   mass_market                0.522473
# 4   mass_market                0.489149
# 5   mass_market                0.489149
# 6   mass_market                0.482857
# 7   mass_market                0.475451
# 8   mass_market                0.463249
# 9   mass_market                0.463249
